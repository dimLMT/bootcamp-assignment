# %%
# Standard Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Additional Imports
import os, json, math, time
from yelpapi import YelpAPI
from tqdm.notebook import tqdm_notebook

# %%
# Load API Credentials
with open('/Users/yupfj/.secret/yelp_api.json') as f:   #use your path here!
    login = json.load(f)
# Instantiate YelpAPI Variable
yelp_api = YelpAPI(login['api-key'], timeout_s=5.0)

# %%
def create_json_file(JSON_FILE, delete_if_exists=False):
    
    ## Check if JSON_FILE exists
    file_exists = os.path.isfile(JSON_FILE)
    
    ## If it DOES exist:
    if file_exists == True:
        
        ## Check if user wants to delete if exists
        if delete_if_exists==True:
            
            print(f"[!] {JSON_FILE} already exists. Deleting previous file...")
            ## delete file and confirm it no longer exits.
            os.remove(JSON_FILE)
            ## Recursive call to function after old file deleted
            create_json_file(JSON_FILE, delete_if_exists=False)
        else:
            print(f"[!] {JSON_FILE} already exists.")            
            
    ## If it does NOT exist:
    else:
        
        ## INFORM USER AND SAVE EMPTY LIST
        print(f"[!] {JSON_FILE} not found. Saving empty list to new file.")
        
        ## CREATE ANY NEEDED FOLDERS
        # Get the Folder Name only
        folder = os.path.dirname(JSON_FILE)

        ## If JSON_FILE included a folder:
        if len(folder)>0:
            # create the folder
            os.makedirs(folder,exist_ok=True)
        ## Save empty list to start the json file
        with open(JSON_FILE,'w') as f:
            json.dump([],f)

# %%
# set our API call parameters 
LOCATION = 'NY, NY'
TERM = 'Thai'
# Specifying JSON_FILE filename (can include a folder)
JSON_FILE = "Data/results_in_progress_NY_Thai.json"

# %%
## Create a new empty json file (delet the previous if it exists)
create_json_file(JSON_FILE, delete_if_exists=True)
n_results = 0
# use our yelp_api variable's search_query method to perform our API call
results = yelp_api.search_query(location=LOCATION,
                                term=TERM,
                               offset=n_results)
## How many results total?
total_results = results['total']
## How many did we get the details for?
results_per_page = len(results['businesses'])
# Use math.ceil to round up for the total number of pages of results.
n_pages = math.ceil((results['total']-n_results)/ results_per_page)
n_pages
# Out:
# [!] Data/results_in_progress_NY_Thai.json already exists. Deleting previous file...
# [!] Data/results_in_progress_NY_Thai.json not found. Saving empty list to new file.
# 145

# %%
for i in tqdm_notebook(range(n_pages)):
    
    ## Read in results in progress file and check the length
    with open(JSON_FILE, 'r') as f:
        previous_results = json.load(f)
    ## save number of results for to use as offset
    n_results = len(previous_results)
    
    if (n_results + results_per_page) > 1000:
        print('Exceeded 1000 api calls. Stopping loop.')
        break
    
    ## use n_results as the OFFSET 
    results = yelp_api.search_query(location=LOCATION,
                                    term=TERM, 
                                    offset=n_results)
    
    ## append new results and save to file
    previous_results.extend(results['businesses'])
    
    # display(previous_results)
    with open(JSON_FILE,'w') as f:
        json.dump(previous_results,f)
    
    time.sleep(.2)
# Out:
#   0%|          | 0/145 [00:00<?, ?it/s]
# Exceeded 1000 api calls. Stopping loop.

# %%
# load final results
final_df = pd.read_json(JSON_FILE)
display(final_df.head(), final_df.tail())
# Out:
#                        id                                 alias  \
# 0  jjJc_CrkB2HodEinB6cWww                     lovemama-new-york
# 1  -XYp6w50XbZfS90YddS5ew                     soothr-new-york-2
# 2  B3_K2kUVbYOU0VaLcj_LTw                 thai-villa-new-york-2
# 3  0IFDnYf3bhqxJR6hVrG7Gw           top-thai-vintage-new-york-3
# 4  egDEaHpDumYHzRUZ8JBU-w  pranakhon-thai-restaurant-new-york-2
#
#                         name  \
# 0                   LoveMama
# 1                     Soothr
# 2                 Thai Villa
# 3           Top Thai Vintage
# 4  Pranakhon Thai Restaurant
#
#                                            image_url  is_closed  \
# 0  https://s3-media1.fl.yelpcdn.com/bphoto/bLlFKT...      False
# 1  https://s3-media2.fl.yelpcdn.com/bphoto/HxjVE7...      False
# 2  https://s3-media1.fl.yelpcdn.com/bphoto/IxshIB...      False
# 3  https://s3-media3.fl.yelpcdn.com/bphoto/-ZoEVV...      False
# 4  https://s3-media1.fl.yelpcdn.com/bphoto/XB_CUH...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/lovemama-new-york?adj...          6540
# 1  https://www.yelp.com/biz/soothr-new-york-2?adj...          1124
# 2  https://www.yelp.com/biz/thai-villa-new-york-2...          4812
# 3  https://www.yelp.com/biz/top-thai-vintage-new-...          1106
# 4  https://www.yelp.com/biz/pranakhon-thai-restau...           285
#
#                                           categories  rating  \
# 0  [{'alias': 'thai', 'title': 'Thai'}, {'alias':...     4.5
# 1  [{'alias': 'thai', 'title': 'Thai'}, {'alias':...     4.5
# 2               [{'alias': 'thai', 'title': 'Thai'}]     4.5
# 3  [{'alias': 'thai', 'title': 'Thai'}, {'alias':...     4.5
# 4  [{'alias': 'thai', 'title': 'Thai'}, {'alias':...     4.5
#
#                                          coordinates  \
# 0  {'latitude': 40.730408722512074, 'longitude': ...
# 1   {'latitude': 40.732259, 'longitude': -73.987363}
# 2     {'latitude': 40.73902, 'longitude': -73.99065}
# 3  {'latitude': 40.729907419973344, 'longitude': ...
# 4     {'latitude': 40.73369, 'longitude': -73.99316}
#
#                                  transactions price  \
# 0  [restaurant_reservation, delivery, pickup]    $$
# 1                          [delivery, pickup]    $$
# 2                          [delivery, pickup]    $$
# 3  [restaurant_reservation, delivery, pickup]    $$
# 4                          [delivery, pickup]   NaN
#
#                                             location         phone  \
# 0  {'address1': '174 2nd Ave', 'address2': '', 'a...  +12122545370
# 1  {'address1': '204 E 13th St', 'address2': '', ...  +12128449789
# 2  {'address1': '5 E 19th St', 'address2': 'G Flo...  +12128029999
# 3  {'address1': '55 Carmine St', 'address2': None...  +16466092272
# 4  {'address1': '88 University Pl', 'address2': N...  +12127866789
#
#     display_phone     distance
# 0  (212) 254-5370  2859.902795
# 1  (212) 844-9789  3043.263183
# 2  (212) 802-9999  3744.570400
# 3  (646) 609-2272  2845.705425
# 4  (212) 786-6789  3144.403563
#                          id                           alias  \
# 995  Qgv2vyUV-DwK8YwrhU-jtw   lan-sheng-restaurant-new-york
# 996  RoXFN-T1s6moM5smbY_5Gw      mee-noodle-shop-new-york-2
# 997  Clumryf360iOnwpZ2ML8aw              sushi-you-new-york
# 998  Vbmv3T7hr_owVic5BQXs5w     din-soup-dumplings-brooklyn
# 999  NU_bgtavUAmLOPpC2cjkjw  bjork-cafe-and-bistro-new-york
#
#                      name                                          image_url  \
# 995  Lan Sheng Restaurant  https://s3-media4.fl.yelpcdn.com/bphoto/9Sm_9s...
# 996       Mee Noodle Shop  https://s3-media3.fl.yelpcdn.com/bphoto/CfzomA...
# 997             Sushi You  https://s3-media3.fl.yelpcdn.com/bphoto/1pw9KM...
# 998    Din Soup Dumplings  https://s3-media2.fl.yelpcdn.com/bphoto/HMlvTY...
# 999   Bjork Cafe & Bistro  https://s3-media2.fl.yelpcdn.com/bphoto/S0lgXd...
#
#      is_closed                                                url  \
# 995      False  https://www.yelp.com/biz/lan-sheng-restaurant-...
# 996      False  https://www.yelp.com/biz/mee-noodle-shop-new-y...
# 997      False  https://www.yelp.com/biz/sushi-you-new-york?ad...
# 998      False  https://www.yelp.com/biz/din-soup-dumplings-br...
# 999      False  https://www.yelp.com/biz/bjork-cafe-and-bistro...
#
#      review_count                                         categories  rating  \
# 995           218       [{'alias': 'szechuan', 'title': 'Szechuan'}]     4.0
# 996           566  [{'alias': 'noodles', 'title': 'Noodles'}, {'a...     3.0
# 997           284  [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     4.0
# 998           203  [{'alias': 'dimsum', 'title': 'Dim Sum'}, {'al...     4.5
# 999            14  [{'alias': 'salad', 'title': 'Salad'}, {'alias...     4.5
#
#                                            coordinates        transactions  \
# 995  {'latitude': 40.7517141867087, 'longitude': -7...  [pickup, delivery]
# 996  {'latitude': 40.7653751, 'longitude': -73.9879...  [pickup, delivery]
# 997   {'latitude': 40.755555, 'longitude': -73.968736}  [pickup, delivery]
# 998  {'latitude': 40.694191000000004, 'longitude': ...  [pickup, delivery]
# 999  {'latitude': 40.74946490113501, 'longitude': -...                  []
#
#     price                                           location         phone  \
# 995    $$  {'address1': '128 W 36th St', 'address2': None...  +12125758899
# 996    $$  {'address1': '795 9th Ave', 'address2': '', 'a...  +12127652929
# 997    $$  {'address1': '246 E 51st St', 'address2': None...  +12127522987
# 998    $$  {'address1': '162 Montague St', 'address2': ''...  +17185503888
# 999   NaN  {'address1': '58 Park Ave', 'address2': '', 'a...  +12127793587
#
#       display_phone     distance
# 995  (212) 575-8899  5169.140152
# 996  (212) 765-2929  6685.637739
# 997  (212) 752-2987  5974.069300
# 998  (718) 550-3888  1257.700623
# 999  (212) 779-3587  5039.839683

# %%
# check for duplicate ID's 
final_df.duplicated(subset='id').sum()
# Out:
# 1

# %%
## Drop duplicate ids and confirm there are no more duplicates
final_df = final_df.drop_duplicates(subset='id')
# save the final results to a compressed csv
csv_file = JSON_FILE.replace('.json', '.csv.gz')
# save the final results to a compressed csv
final_df.to_csv(csv_file, compression='gzip',index=False)
